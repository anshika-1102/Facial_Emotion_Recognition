# %% [markdown]
# <a href="https://colab.research.google.com/github/anshika-1102/Facial_Emotion_Recognition/blob/main/evaluation_metrics_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Accuracy bar graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch

# Sample data
data = {
    'model_name': ['EfficientNet', 'VGG', 'ResNet'],
    'Accuracy': [0.366935, 0.193548, 0.298387],
}

# Create a beautiful color palette
palette = sns.color_palette("muted")

# Create a bar graph for Accuracy
plt.figure(figsize=(8, 6))
ax = sns.barplot(x='model_name', y='Accuracy', data=data, palette=palette)

# Display values above each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height():.4f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                textcoords='offset points')

plt.title('Accuracy Comparison')
plt.xlabel('Model Name')
plt.ylabel('Accuracy')

# Create a custom legend with colors and model names
legend_patches = [Patch(color=color, label=model_name) for color, model_name in zip(palette, data['model_name'])]
plt.legend(handles=legend_patches, title='Models',loc='upper center', bbox_to_anchor=(0.5, 1))
plt.show()

# %% [markdown]
# # Precision bar graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch

# Sample data
data = {
    'model_name': ['EfficientNet', 'VGG', 'ResNet'],
    'Precision': [0.403429, 0.202163, 0.331755],
}

# Create a beautiful color palette
palette = sns.color_palette("muted")

# Create a bar graph for Precision
plt.figure(figsize=(8, 6))
ax = sns.barplot(x='model_name', y='Precision', data=data, palette=palette)

# Display values above each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height():.4f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                textcoords='offset points')

plt.title('Precision Comparison')
plt.xlabel('Model Name')
plt.ylabel('Precision')

# Create a custom legend with colors and model names
legend_patches = [Patch(color=color, label=model_name) for color, model_name in zip(palette, data['model_name'])]
plt.legend(handles=legend_patches, title='Models',loc='upper center', bbox_to_anchor=(0.5, 1))
plt.show()

# %% [markdown]
# # Recall bar graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch

# Sample data
data = {
    'model_name': ['EfficientNet', 'VGG', 'ResNet'],
    'Recall': [0.366935, 0.193548, 0.298387],
}

# Create a beautiful color palette
palette = sns.color_palette("muted")

# Create a bar graph for Recall
plt.figure(figsize=(8, 6))
ax = sns.barplot(x='model_name', y='Recall', data=data, palette=palette)

# Display values above each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height():.4f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                textcoords='offset points')

plt.title('Recall Comparison')
plt.xlabel('Model Name')
plt.ylabel('Recall')

# Create a custom legend with colors and model names
legend_patches = [Patch(color=color, label=model_name) for color, model_name in zip(palette, data['model_name'])]
plt.legend(handles=legend_patches, title='Models',loc='upper center', bbox_to_anchor=(0.5, 1))
plt.show()

# %% [markdown]
# # F1-Score bar graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch

# Sample data
data = {
    'model_name': ['EfficientNet', 'VGG', 'ResNet'],
    'F1 Score': [0.359769, 0.180351, 0.297495],
}

# Create a beautiful color palette
palette = sns.color_palette("muted")

# Create a bar graph for F1 Score
plt.figure(figsize=(8, 6))
ax = sns.barplot(x='model_name', y='F1 Score', data=data, palette=palette)

# Display values above each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height():.4f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                textcoords='offset points')

plt.title('F1 Score Comparison')
plt.xlabel('Model Name')
plt.ylabel('F1 Score')

# Create a custom legend with colors and model names
legend_patches = [Patch(color=color, label=model_name) for color, model_name in zip(palette, data['model_name'])]
plt.legend(handles=legend_patches, title='Models',loc='upper center', bbox_to_anchor=(0.5, 1))

plt.show()
